# %%
ls imagery/series_6x2_BL_PM
# Out:
# change_bmap.tif                        S1_20180623_6x2_BL_PM_sub_warp.tif
# change_cmap.tif                        S1_20180705_6x2_BL_PM_sub.tif
# change_fmap.tif                        S1_20180705_6x2_BL_PM_sub_warp.tif
# change_smap.tif                        S1_20180717_6x2_BL_PM_sub.tif
# S1_20180412_6x2_BL_PM_sub_sub_enl.tif  S1_20180717_6x2_BL_PM_sub_warp.tif
# S1_20180412_6x2_BL_PM_sub_sub.tif      S1_20180729_6x2_BL_PM_sub.tif
# S1_20180412_6x2_BL_PM_sub.tif          S1_20180729_6x2_BL_PM_sub_warp.tif
# S1_20180424_6x2_BL_PM_sub.tif          S1_20180810_6x2_BL_PM_sub.tif
# S1_20180424_6x2_BL_PM_sub_warp.tif     S1_20180810_6x2_BL_PM_sub_warp.tif
# S1_20180506_6x2_BL_PM_sub.tif          S1_20180822_6x2_BL_PM_sub.tif
# S1_20180506_6x2_BL_PM_sub_warp.tif     S1_20180822_6x2_BL_PM_sub_warp.tif
# S1_20180518_6x2_BL_PM_sub.tif          S1_20180903_6x2_BL_PM_sub.tif
# S1_20180518_6x2_BL_PM_sub_warp.tif     S1_20180903_6x2_BL_PM_sub_warp.tif
# ...

# %%
# !scripts/run_sar_seqQ.sh S1_2 imagery/series_6x2_BL_PM/ 13.0 0.0001
# Out:
# S1_2
# imagery/series_6x2_BL_PM/S1_20180412_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180424_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180506_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180518_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180530_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180611_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180623_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180705_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180717_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180729_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180810_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180822_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180903_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180915_6x2_BL_PM_sub_warp.tif imagery/series_6x2_BL_PM/S1_20180927_6x2_BL_PM_sub_warp.tif
# ...
#      Multi-temporal SAR Change Detection
# ...
# Mon Jun 17 19:50:02 2019
# ...

# %%
run scripts/dispms -f imagery/series_6x2_BL_PM/sarseqQ_fmap.tif -c -d [0,0,400,400]
