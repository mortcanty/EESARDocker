# %%
ls imagery/
# Out:
# bmapAA1.tif   S1_20180506/  S1_20180705/  S1_20180903/      s1_ffa_bmap.tif
# bmapAA.tif    S1_20180518/  S1_20180717/  S1_20180915/      s1_ffa.tif
# bmapMC.tif    S1_20180530/  S1_20180729/  S1_20180927/      series_6x2_BL_PM/
# S1_20180412/  S1_20180611/  S1_20180810/  S1_20190125/
# S1_20180424/  S1_20180623/  S1_20180822/  s1_ffa1_bmap.tif

# %%
# %matplotlib inline

# %%
run scripts/dispms -f imagery/s1_ffa.tif -p [1,3,3]

# %%
run scripts/dispms -f imagery/bmapMC.tif -d [670,470,200,200] -p [1,2,3] -e 1 -F imagery/bmapAA1.tif -P [1,2,3] -D [600,400,200,200] -E 1

# %%
run scripts/dispms -f imagery/bmapMC.tif -p [1,2,3] -e 1
